# %% [markdown]
# ## 0_기본 설정

# %% [markdown]
# ### 라이브러리 불러오기

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 랜덤시드 설정

# %%
RANDOM_SEED = 42

# %% [markdown]
# ### 데이터 불러오기

# %%
path_train = "../../../data/train/"  # 알잘딱 수정
path_eval = "../../../data/eval/"    # 알잘딱 수정

train_ratings = pd.read_csv(path_train + 'train_ratings.csv')
sample_submission = pd.read_csv(path_eval + 'sample_submission.csv')

directors_df = pd.read_csv(path_train + 'directors.tsv', sep='\t')
genres_df = pd.read_csv(path_train + 'genres.tsv', sep='\t')
titles_df = pd.read_csv(path_train + 'titles.tsv', sep='\t')
writers_df = pd.read_csv(path_train + 'writers.tsv', sep='\t')
years_df = pd.read_csv(path_train + 'years.tsv', sep='\t')

# %%
train_ratings
# Out:
#            user   item        time
# 0            11   4643  1230782529
# 1            11    170  1230782534
# 2            11    531  1230782539
# 3            11    616  1230782542
# 4            11   2140  1230782563
# ...         ...    ...         ...
# 5154466  138493  44022  1260209449
# 5154467  138493   4958  1260209482
# 5154468  138493  68319  1260209720
# 5154469  138493  40819  1260209726
# 5154470  138493  27311  1260209807
#
# [5154471 rows x 3 columns]

# %%
# 각 데이터 확인 (알잘딱 수정 후 사용)

directors_df.tail()
# genres_df.head()
# titles_df.head()
# writers_df.head()
# years_df.head()
# Out:
#        item   director
# 5900  84273  nm2879822
# 5901  58376  nm2879822
# 5902  65225  nm2879822
# 5903   2394  nm9054338
# 5904  55768  nm9054338

# %% [markdown]
# ## 1_item 별 directors, genres, titles, writers, years 중복여부 확인

# %% [markdown]
# ### 1 directors

# %%
directors_df_sorted = directors_df.sort_values(by='item', ascending=True) \
                                  .set_index('item')    # reset_index(drop=True): 기존 인덱스 열 삭제 코드
directors_df_sorted.head(20)
# Out:
#        director
# item
# 1     nm0005124
# 2     nm0002653
# 3     nm0222043
# 4     nm0001845
# 5     nm0796124
# 6     nm0000520
# 7     nm0001628
# 8     nm0382072
# 9     nm0001382
# 10    nm0132709
# 11    nm0001661
# 12    nm0000316
# 13    nm0920425
# 14    nm0000231
# 15    nm0001317
# 16    nm0000217
# 17    nm0000487
# 18    nm0000233
# 18    nm0001675
# 18    nm0005062

# %%
directors_df_duplicated = directors_df_sorted.groupby('item')['director'].apply(lambda x: ', '.join(x.unique())).reset_index()
directors_df_duplicated.head(20)
# Out:
#     item                         director
# 0      1                        nm0005124
# 1      2                        nm0002653
# 2      3                        nm0222043
# 3      4                        nm0001845
# 4      5                        nm0796124
# 5      6                        nm0000520
# 6      7                        nm0001628
# 7      8                        nm0382072
# 8      9                        nm0001382
# 9     10                        nm0132709
# 10    11                        nm0001661
# 11    12                        nm0000316
# 12    13                        nm0920425
# 13    14                        nm0000231
# 14    15                        nm0001317
# 15    16                        nm0000217
# 16    17                        nm0000487
# 17    18  nm0000233, nm0001675, nm0005062
# 18    19                        nm0644203
# 19    20                        nm0747849

# %% [markdown]
# ### 2 genres

# %%
genres_df_sorted = genres_df.sort_values(by='item', ascending=True) \
                                  .set_index('item')    # reset_index(drop=True): 기존 인덱스 열 삭제 코드
genres_df_sorted.head(20)
# Out:
#           genre
# item
# 1     Animation
# 1       Fantasy
# 1     Adventure
# 1      Children
# 1        Comedy
# 2       Fantasy
# 2     Adventure
# 2      Children
# 3       Romance
# 3        Comedy
# 4        Comedy
# 4         Drama
# 4       Romance
# 5        Comedy
# 6      Thriller
# 6         Crime
# 6        Action
# 7       Romance
# 7        Comedy
# 8      Children

# %%
genres_df_duplicated = genres_df_sorted.groupby('item')['genre'].apply(lambda x: ', '.join(x.unique())).reset_index()
genres_df_duplicated.head(20)
# Out:
#     item                                            genre
# 0      1  Animation, Fantasy, Adventure, Children, Comedy
# 1      2                     Fantasy, Adventure, Children
# 2      3                                  Romance, Comedy
# 3      4                           Comedy, Drama, Romance
# 4      5                                           Comedy
# 5      6                          Thriller, Crime, Action
# 6      7                                  Romance, Comedy
# 7      8                              Children, Adventure
# 8      9                                           Action
# 9     10                      Thriller, Action, Adventure
# 10    11                           Romance, Drama, Comedy
# 11    12                                   Comedy, Horror
# 12    13                   Adventure, Animation, Children
# 13    14                                            Drama
# 14    15                       Romance, Adventure, Action
# 15    16                                     Crime, Drama
# 16    17                                   Drama, Romance
# 17    18                                           Comedy
# 18    19                                           Comedy
# 19    20           Thriller, Action, Comedy, Crime, Drama

# %% [markdown]
# ### 3 titles

# %%
titles_df_sorted = titles_df.sort_values(by='item', ascending=True) \
                                  .set_index('item')    # reset_index(drop=True): 기존 인덱스 열 삭제 코드
titles_df_sorted.head(20)
# Out:
#                                       title
# item
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
# 6                               Heat (1995)
# 7                            Sabrina (1995)
# 8                       Tom and Huck (1995)
# 9                       Sudden Death (1995)
# 10                         GoldenEye (1995)
# 11           American President, The (1995)
# 12       Dracula: Dead and Loving It (1995)
# 13                             Balto (1995)
# 14                             Nixon (1995)
# 15                  Cutthroat Island (1995)
# 16                            Casino (1995)
# 17             Sense and Sensibility (1995)
# 18                        Four Rooms (1995)
# 19    Ace Ventura: When Nature Calls (1995)
# 20                       Money Train (1995)

# %% [markdown]
# 중복값 확인

# %%
titles_df_repeated = titles_df_sorted.duplicated(subset='title', keep=False)
titles_df_repeated
# Out:
# item
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
#           ...
# 118700    False
# 118900    False
# 118997    False
# 119141    False
# 119145    False
# Length: 6807, dtype: bool

# %%
# 중복되는 title 갯수
num_repeated = (titles_df_repeated == True).sum()
num_repeated
# Out:
# 2

# %%
# 중복되는 title의 item 고유번호
titles_df_repeated[titles_df_repeated == True]
# Out:
# item
# 34048    True
# 64997    True
# dtype: bool

# %%
# 중복된 영화의 title
titles_df_sorted.loc[[34048, 64997], 'title']
# Out:
# item
# 34048    War of the Worlds (2005)
# 64997    War of the Worlds (2005)
# Name: title, dtype: object

# %%
titles_df_duplicated = titles_df_sorted.groupby('item')['title'].apply(lambda x: ', '.join(x.unique())).reset_index().set_index('item')
titles_df_duplicated
# Out:
#                                       title
# item
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
# ...                                     ...
# 118700                         Selma (2014)
# 118900                          Wild (2014)
# 118997                Into the Woods (2014)
# 119141                 The Interview (2014)
# 119145  Kingsman: The Secret Service (2015)
#
# [6807 rows x 1 columns]

# %%
# print(titles_df_duplicated['item'] == 34048)  # 일반 컬럼으로 설정 시
# print(titles_df_duplicated['item'] == 64997)
# print(titles_df_duplicated.loc[34048])  # 인덱스로 설정 시
# print(titles_df_duplicated.loc[64997])

# titles_df_duplicated.loc[34000:34070]

# %% [markdown]
# ### 4 writers

# %%
writers_df_sorted = writers_df.sort_values(by='item', ascending=True) \
                              .set_index('item')    # reset_index(drop=True): 기존 인덱스 열 삭제 코드
writers_df_sorted.head(20)
# Out:
#          writer
# item
# 1     nm0169505
# 1     nm0812513
# 1     nm0004056
# 1     nm0710020
# 1     nm0230032
# 1     nm0923736
# 1     nm0005124
# 2     nm0885575
# 2     nm0852430
# 2     nm0378144
# 3     nm0425756
# 4     nm0060103
# 5     nm0352443
# 5     nm0329304
# 5     nm0796124
# 5     nm0583600
# 6     nm0000520
# 7     nm0499626
# 7     nm0853138
# 7     nm0713128

# %%
writers_df_duplicated = writers_df_sorted.groupby('item')['writer'].apply(lambda x: ', '.join(x.unique())).reset_index()
writers_df_duplicated.head(20)
# Out:
#     item                                             writer
# 0      1  nm0169505, nm0812513, nm0004056, nm0710020, nm...
# 1      2                    nm0885575, nm0852430, nm0378144
# 2      3                                          nm0425756
# 3      4                                          nm0060103
# 4      5         nm0352443, nm0329304, nm0796124, nm0583600
# 5      6                                          nm0000520
# 6      7  nm0499626, nm0853138, nm0713128, nm0000697, nm...
# 7      8                    nm0521739, nm0878494, nm0814085
# 8      9                                          nm0704164
# 9     10         nm0270761, nm0289833, nm0128997, nm0001220
# 10    11                                          nm0815070
# 11    12                    nm0000316, nm0831290, nm0209918
# 12    13                                          nm0776107
# 13    14                    nm0000231, nm0929349, nm0729151
# 14    15  nm0317279, nm0635565, nm0065847, nm0455207, nm...
# 15    16                               nm0000217, nm0683380
# 16    17                               nm0000807, nm0000668
# 17    18                               nm0000233, nm0001675
# 18    19                               nm0644203, nm0077062
# 19    20                               nm0724514, nm0521739

# %% [markdown]
# ### 5 years

# %%
years_df_sorted = years_df.sort_values(by='item', ascending=True) \
                                  .set_index('item')    # reset_index(drop=True): 기존 인덱스 열 삭제 코드
years_df_sorted
# Out:
#         year
# item
# 1       1995
# 2       1995
# 3       1995
# 4       1995
# 5       1995
# ...      ...
# 118696  2014
# 118700  2014
# 118900  2014
# 118997  2014
# 119141  2014
#
# [6799 rows x 1 columns]

# %%
years_df_repeated = years_df_sorted.duplicated(subset='year', keep=False)
years_df_repeated
# Out:
# item
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
#           ...
# 118696    True
# 118700    True
# 118900    True
# 118997    True
# 119141    True
# Length: 6799, dtype: bool

# %%
# 중복되는 years 갯수
num_repeated_years = (years_df_repeated == False).sum()
num_repeated_years
# Out:
# 0

# %% [markdown]
# 중복값 없음 -> 따로 처리 안해도 될듯

# %%
years_df_duplicated = years_df_sorted

# years_df_duplicated = years_df_sorted.groupby('item')['years'].apply(lambda x: ', '.join(x.unique())).reset_index()
# years_df_duplicated.head(20)

# %% [markdown]
# ## 2_영화 정보 종합해서 한눈에 확인

# %%
# 공통 열 'item'기준으로 병합
movie_info = titles_df_duplicated.merge(genres_df_duplicated, on='item', how='outer') \
                      .merge(years_df_duplicated, on='item', how='outer') \
                      .merge(directors_df_duplicated, on='item', how='outer') \
                      .merge(writers_df_duplicated, on='item', how='outer')

# %%
movie_info.head(10)
# Out:
#    item                               title  \
# 0     1                    Toy Story (1995)
# 1     2                      Jumanji (1995)
# 2     3             Grumpier Old Men (1995)
# 3     4            Waiting to Exhale (1995)
# 4     5  Father of the Bride Part II (1995)
# 5     6                         Heat (1995)
# 6     7                      Sabrina (1995)
# 7     8                 Tom and Huck (1995)
# 8     9                 Sudden Death (1995)
# 9    10                    GoldenEye (1995)
#
#                                              genre    year   director  \
# 0  Animation, Fantasy, Adventure, Children, Comedy  1995.0  nm0005124
# 1                     Fantasy, Adventure, Children  1995.0  nm0002653
# 2                                  Romance, Comedy  1995.0  nm0222043
# 3                           Comedy, Drama, Romance  1995.0  nm0001845
# 4                                           Comedy  1995.0  nm0796124
# 5                          Thriller, Crime, Action  1995.0  nm0000520
# 6                                  Romance, Comedy  1995.0  nm0001628
# 7                              Children, Adventure  1995.0  nm0382072
# 8                                           Action  1995.0  nm0001382
# 9                      Thriller, Action, Adventure  1995.0  nm0132709
#
#                                               writer
# 0  nm0169505, nm0812513, nm0004056, nm0710020, nm...
# 1                    nm0885575, nm0852430, nm0378144
# 2                                          nm0425756
# 3                                          nm0060103
# 4         nm0352443, nm0329304, nm0796124, nm0583600
# 5                                          nm0000520
# 6  nm0499626, nm0853138, nm0713128, nm0000697, nm...
# 7                    nm0521739, nm0878494, nm0814085
# 8                                          nm0704164
# 9         nm0270761, nm0289833, nm0128997, nm0001220

# %% [markdown]
# ## 3_사용자의 행동 분석

# %% [markdown]
# ### 1 각 사용자가 평가한 영화 수 분포

# %%
user_movie_counts = train_ratings.groupby('user')['item'].count()

# 사용자별 평가 영화 수 히스토그램
plt.figure(figsize=(10, 5))
plt.hist(user_movie_counts, bins=30, edgecolor='black', alpha=0.7)
plt.title("Distribution of Movies Rated by Users")
plt.xlabel("Number of Movies Rated")
plt.ylabel("Number of Users")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### 2 각 영화가 평가받은 횟수 분포

# %%
movie_user_counts = train_ratings.groupby('item')['user'].count()

# 영화별 평가 받은 횟수 히스토그램
plt.figure(figsize=(10, 5))
plt.hist(movie_user_counts, bins=30, edgecolor='black', alpha=0.7)
plt.title("Distribution of Ratings per Movie")
plt.xlabel("Number of Ratings Received")
plt.ylabel("Number of Movies")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### 3 사용자와 영화의 평가 분포 요약

# %%
user_stats = user_movie_counts.describe()
movie_stats = movie_user_counts.describe()

# %%
# 사용자 행동 분석 통계 데이터 출력
user_stats, movie_stats
# Out:
# (count    31360.000000
#  mean       164.364509
#  std        150.009107
#  min         16.000000
#  25%         71.000000
#  50%        114.000000
#  75%        200.000000
#  max       2912.000000
#  Name: item, dtype: float64,
#  count     6807.000000
#  mean       757.230939
#  std       1682.973090
#  min         27.000000
#  25%         90.000000
#  50%        197.000000
#  75%        610.500000
#  max      19699.000000
#  Name: user, dtype: float64)

# %% [markdown]
# ### 4 한 유저가 같은 작품을 두 번 이상 평가한적 있는지 확인

# %%
duplicate_ratings = train_ratings.duplicated(subset=['user', 'item'], keep=False)
duplicate_ratings
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 5154466    False
# 5154467    False
# 5154468    False
# 5154469    False
# 5154470    False
# Length: 5154471, dtype: bool

# %%
num_duplicates = duplicate_ratings.sum()
num_duplicates
# Out:
# 0
